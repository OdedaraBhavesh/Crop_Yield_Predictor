# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./Dataset/yield_df.csv")
data
# Out:
#        Unnamed: 0      Area            Item  Year  hg/ha_yield  \
# 0               0   Albania           Maize  1990        36613
# 1               1   Albania        Potatoes  1990        66667
# 2               2   Albania     Rice, paddy  1990        23333
# 3               3   Albania         Sorghum  1990        12500
# 4               4   Albania        Soybeans  1990         7000
# ...           ...       ...             ...   ...          ...
# 28237       28237  Zimbabwe     Rice, paddy  2013        22581
# 28238       28238  Zimbabwe         Sorghum  2013         3066
# 28239       28239  Zimbabwe        Soybeans  2013        13142
# 28240       28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241       28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                             1485.0             121.00     16.37
# 1                             1485.0             121.00     16.37
# ...

# %%
data.drop('Unnamed: 0',inplace=True,axis=1)  # Axis=1 it means column wise

# %%
data.head()
# Out:
#       Area         Item  Year  hg/ha_yield  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990        36613                         1485.0
# 1  Albania     Potatoes  1990        66667                         1485.0
# 2  Albania  Rice, paddy  1990        23333                         1485.0
# 3  Albania      Sorghum  1990        12500                         1485.0
# 4  Albania     Soybeans  1990         7000                         1485.0
#
#    pesticides_tonnes  avg_temp
# 0              121.0     16.37
# 1              121.0     16.37
# 2              121.0     16.37
# 3              121.0     16.37
# 4              121.0     16.37

# %%
data.shape
# Out:
# (28242, 7)

# %%
data.isnull().sum()
# Out:
# Area                             0
# Item                             0
# Year                             0
# hg/ha_yield                      0
# average_rain_fall_mm_per_year    0
# pesticides_tonnes                0
# avg_temp                         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28242 entries, 0 to 28241
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area                           28242 non-null  object
#  1   Item                           28242 non-null  object
#  2   Year                           28242 non-null  int64
#  3   hg/ha_yield                    28242 non-null  int64
#  4   average_rain_fall_mm_per_year  28242 non-null  float64
#  5   pesticides_tonnes              28242 non-null  float64
#  6   avg_temp                       28242 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.5+ MB

# %%
data.duplicated().sum()
# Out:
# np.int64(2310)

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.describe()
# Out:
#                Year    hg/ha_yield  average_rain_fall_mm_per_year  \
# count  25932.000000   25932.000000                   25932.000000
# mean    2001.556455   76978.132925                    1146.836688
# std        7.055924   84647.605552                     717.391098
# min     1990.000000      50.000000                      51.000000
# 25%     1995.000000   19996.000000                     593.000000
# 50%     2001.000000   39530.000000                    1083.000000
# 75%     2008.000000  104168.000000                    1668.000000
# max     2013.000000  501412.000000                    3240.000000
#
#        pesticides_tonnes      avg_temp
# count       25932.000000  25932.000000
# mean        34782.573241     20.422251
# std         57228.568244      6.439402
# min             0.040000      1.300000
# 25%          1597.000000     16.580000
# 50%         15373.000000     21.420000
# 75%         45620.000000     26.060000
# max        367778.000000     30.650000

# %%
data["average_rain_fall_mm_per_year"].unique()
# Out:
# array([1485.,   89., 1010.,  591.,  562.,  534., 1110.,  447., 1292.,
#          83., 2666.,  618.,  847.,  416., 1761.,  608.,  748., 1274.,
#        1604.,  537., 1342., 1522., 3240., 1113.,  703., 1410., 2274.,
#          51., 1784.,  383.,  626.,  536.,  867.,  700., 1187.,  652.,
#        1996., 1651., 2387., 1440., 1976.,  589., 1083., 2702.,  216.,
#        1118.,  832., 2051., 1668.,  250.,  630.,  641.,  661.,  788.,
#          56.,  656., 1513., 1181., 2875.,  282.,   92., 2041.,  758.,
#         241.,  346., 1032.,  285., 1500.,  778., 1732., 2280.,  151.,
#        1414.,  494., 3142., 1738.,  600.,  854.,   74.,  637., 1212.,
#          59.,  686., 1162.,  495.,  636., 1712., 2331.,  624., 1537.,
#         691., 1622.,  207.,  593., 1180.,  565., 1220., 1300., 1020.,
#         657.])

# %%
data
# Out:
#            Area            Item  Year  hg/ha_yield  \
# 0       Albania           Maize  1990        36613
# 1       Albania        Potatoes  1990        66667
# 2       Albania     Rice, paddy  1990        23333
# 3       Albania         Sorghum  1990        12500
# 4       Albania        Soybeans  1990         7000
# ...         ...             ...   ...          ...
# 28237  Zimbabwe     Rice, paddy  2013        22581
# 28238  Zimbabwe         Sorghum  2013         3066
# 28239  Zimbabwe        Soybeans  2013        13142
# 28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                             1485.0             121.00     16.37
# 1                             1485.0             121.00     16.37
# 2                             1485.0             121.00     16.37
# 3                             1485.0             121.00     16.37
# ...

# %%
data["hg/ha_yield"]=data["hg/ha_yield"].astype(np.float64)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25932 entries, 0 to 28241
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area                           25932 non-null  object
#  1   Item                           25932 non-null  object
#  2   Year                           25932 non-null  int64
#  3   hg/ha_yield                    25932 non-null  float64
#  4   average_rain_fall_mm_per_year  25932 non-null  float64
#  5   pesticides_tonnes              25932 non-null  float64
#  6   avg_temp                       25932 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 1.6+ MB

# %%
data['Area']=data['Area'].str.strip().str.title()
data['Item']=data['Item'].str.strip().str.title()

# %%
plt.figure(figsize=(10,20))
sns.countplot(y=data['Area'])
plt.show()

# %%
country = data['Area'].unique()

# %%
yeild_per_country = []
for cou in country:
    yeild_per_country.append(data[data['Area']==cou]['hg/ha_yield'].sum())

# %%
data['hg/ha_yield'].sum()
# Out:
# np.float64(1996196943.0)

# %%
yeild_per_country
# Out:
# [np.float64(5711536.0),
#  np.float64(6711464.0),
#  np.float64(5722563.0),
#  np.float64(32864032.0),
#  np.float64(4524100.0),
#  np.float64(109111062.0),
#  np.float64(10852258.0),
#  np.float64(4608380.0),
#  np.float64(4384717.0),
#  np.float64(4443889.0),
#  np.float64(7720159.0),
#  np.float64(4704812.0),
#  np.float64(8442270.0),
#  np.float64(470651.0),
#  np.float64(136340329.0),
#  np.float64(6263075.0),
#  np.float64(6083337.0),
#  np.float64(7031146.0),
#  np.float64(10717883.0),
#  np.float64(34706922.0),
#  np.float64(4255627.0),
#  np.float64(20561214.0),
#  np.float64(26927138.0),
#  np.float64(6083167.0),
#  np.float64(10701651.0),
#  np.float64(25312166.0),
#  np.float64(21315591.0),
#  np.float64(36828848.0),
#  np.float64(16855944.0),
#  np.float64(1452416.0),
#  np.float64(3595638.0),
#  np.float64(6210668.0),
#  np.float64(15790618.0),
#  np.float64(38780463.0),
#  np.float64(9260371.0),
#  np.float64(14571925.0),
#  np.float64(16508723.0),
# ...

# %%
plt.figure(figsize=(10,20))
sns.barplot(y=country,x=yeild_per_country)
# Out:
# <Axes: >

# %%
data['Item'].value_counts()
# Out:
# Item
# Potatoes                3956
# Maize                   3824
# Wheat                   3539
# Rice, Paddy             3091
# Soybeans                2940
# Sorghum                 2770
# Sweet Potatoes          2593
# Cassava                 1889
# Yams                     774
# Plantains And Others     556
# Name: count, dtype: int64

# %%
sns.countplot(y=data['Item'])
# Out:
# <Axes: xlabel='count', ylabel='Item'>

# %%
crops = (data['Item'].unique())

# %%
yield_per_item = []
for crop in crops:
    yield_per_item.append(data[data['Item']==crop]['hg/ha_yield'].sum())

# %%
yield_per_item
# Out:
# [np.float64(142020761.0),
#  np.float64(785921609.0),
#  np.float64(127646024.0),
#  np.float64(52906376.0),
#  np.float64(49957039.0),
#  np.float64(106614786.0),
#  np.float64(275132269.0),
#  np.float64(310269345.0),
#  np.float64(58958974.0),
#  np.float64(86769760.0)]

# %%
sns.barplot(y=crops,x=yield_per_item)
plt.ylabel("CROPS")
plt.show()

# %%
data.sample(2)
# Out:
#              Area      Item  Year  hg/ha_yield  average_rain_fall_mm_per_year  \
# 8524  El Salvador  Potatoes  2006     220517.0                         1784.0
# 4878     Bulgaria     Wheat  1999      27352.0                          608.0
#
#       pesticides_tonnes  avg_temp
# 8524            2265.72     26.14
# 4878            3004.75      9.67

# %%
x=['Year','average_rain_fall_mm_per_year','pesticides_tonnes','avg_temp','Area','Item','hg/ha_yield']
data = data[x]

# %%
data
# Out:
#        Year  average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp  \
# 0      1990                         1485.0             121.00     16.37
# 1      1990                         1485.0             121.00     16.37
# 2      1990                         1485.0             121.00     16.37
# 3      1990                         1485.0             121.00     16.37
# 4      1990                         1485.0             121.00     16.37
# ...     ...                            ...                ...       ...
# 28237  2013                          657.0            2550.07     19.76
# 28238  2013                          657.0            2550.07     19.76
# 28239  2013                          657.0            2550.07     19.76
# 28240  2013                          657.0            2550.07     19.76
# 28241  2013                          657.0            2550.07     19.76
#
#            Area            Item  hg/ha_yield
# 0       Albania           Maize      36613.0
# ...

# %%
x=data.iloc[:,:6]
y=data.iloc[:,6:]
x
# Out:
#        Year  average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp  \
# 0      1990                         1485.0             121.00     16.37
# 1      1990                         1485.0             121.00     16.37
# 2      1990                         1485.0             121.00     16.37
# 3      1990                         1485.0             121.00     16.37
# 4      1990                         1485.0             121.00     16.37
# ...     ...                            ...                ...       ...
# 28237  2013                          657.0            2550.07     19.76
# 28238  2013                          657.0            2550.07     19.76
# 28239  2013                          657.0            2550.07     19.76
# 28240  2013                          657.0            2550.07     19.76
# 28241  2013                          657.0            2550.07     19.76
#
#            Area            Item
# 0       Albania           Maize
# 1       Albania        Potatoes
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (20745, 6)
# (5187, 6)

# %%
x_train
# Out:
#        Year  average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp  \
# 24234  2000                           59.0            3024.11     26.55
# 9468   2012                          652.0            8002.20     18.82
# 6793   2006                         3240.0           98328.63     27.51
# 28212  2010                          657.0            3305.17     21.17
# 7358   2007                         1410.0            5689.80     27.08
# ...     ...                            ...                ...       ...
# 23678  2004                          854.0           16942.00     16.31
# 5960   2006                          537.0           36572.75      7.85
# 860    1991                          534.0           17866.00     18.73
# 17223  1998                          250.0            6416.14      6.94
# 25918  1994                         2331.0             178.50     26.82
#
#                      Area            Item
# 24234        Saudi Arabia         Sorghum
# ...

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer

# %%
ohe=OneHotEncoder(drop='first')
ss=StandardScaler()

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('onehotencoder',ohe,[4,5]),
        ('standarizer',ss,[0,1,2,3])
    ],
    remainder='passthrough'
)

# %%
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('onehotencoder', OneHotEncoder(drop='first'),
#                                  [4, 5]),
#                                 ('standarizer', StandardScaler(),
#                                  [0, 1, 2, 3])])

# %%
x_train_dummy=preprocessor.fit_transform(x_train)
x_test_dummy=preprocessor.fit_transform(x_test)

# %%
x_train_dummy
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 122877 stored elements and shape (20745, 113)>

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error,r2_score

# %%
models={
    'lr':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'knr':KNeighborsRegressor(),
    'dtr':DecisionTreeRegressor()
}

for name,mod in models.items():
    mod.fit(x_train_dummy,y_train)
    y_pred = mod.predict(x_test_dummy)

    print(f"{name} MSE : {mean_squared_error(y_test,y_pred)} Score: {r2_score(y_test,y_pred)}")
            # take the algorithm which has less MSE and HIGH R2_Score
# Out:
# lr MSE : 1821769507.6917467 Score: 0.7486483313227018
# B:\MachineLearning\MlEnv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43166910887.44141, tolerance: 14819338848.544128
#   model = cd_fast.sparse_enet_coordinate_descent(
# Lasso MSE : 1822352597.4122243 Score: 0.7485678817523188
# Ridge MSE : 1822656055.8741565 Score: 0.7485260132335743
# knr MSE : 124881646.97772121 Score: 0.9827699331762387
# dtr MSE : 482653269.2444573 Score: 0.9334077642067578

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train_dummy,y_train)
dtr.predict(x_test_dummy)
# Out:
# array([ 22411.,  15838.,  71988., ...,  52692.,   9621., 279000.])

# %%
def prediction(Year,average_rain_fall_mm_per_year,pesticides_tonnes,avg_temp,Area,Item):
    features = np.array([[Year,average_rain_fall_mm_per_year,pesticides_tonnes,avg_temp,Area,Item]])

    transformed_Features=preprocessor.transform(features)
    
    predicted_value=dtr.predict(transformed_Features).reshape(1,-1)
    return predicted_value[0]

# %%
Year = 2000
average_rain_fall_mm_per_year = 59.0	
pesticides_tonnes = 3024.11
avg_temp = 26.55
Area = "Saudi Arabia"
Item = "Sorghum"

results = prediction(Year,average_rain_fall_mm_per_year,pesticides_tonnes,avg_temp,Area,Item)
# Out:
# B:\MachineLearning\MlEnv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# B:\MachineLearning\MlEnv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
results
# Out:
# array([11049.])

# %%
import pickle

# %%
pickle.dump(dtr,open('dtr.pkl','wb'))
pickle.dump(preprocessor,open('preprocessor.pkl','wb'))

# %%
# Out:
#       Year  average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp  \
# 5077  2006                          748.0             109.24     28.92
#
#               Area     Item  hg/ha_yield
# 5077  Burkina Faso  Cassava        21316
